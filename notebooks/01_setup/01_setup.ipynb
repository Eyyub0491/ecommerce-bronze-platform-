# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS brazilian_ecommerce_storage
URL 'abfss://brazilian-ecommerce-storage@dlspl21databricks.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL databricks_uc_connector)
COMMENT 'Storage for Brazilian Ecommerce project';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS dbr_dev.brazilian_ecommerce_bronze;

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS dbr_dev.brazilian_ecommerce_bronze.landing
LOCATION 'abfss://brazilian-ecommerce-storage@dlspl21databricks.dfs.core.windows.net/landing';

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS dbr_dev.brazilian_ecommerce_bronze.checkpoints
LOCATION 'abfss://brazilian-ecommerce-storage@dlspl21databricks.dfs.core.windows.net/checkpoints';

# %%
# %sql DESCRIBE VOLUME dbr_dev.brazilian_ecommerce_bronze.landing

# %%
dbutils.secrets.list("ecommerce-bronze-scope")

# %%
display(
    dbutils.fs.ls(
        "/Volumes/dbr_dev/brazilian_ecommerce_bronze/landing/customers"
    )
)
