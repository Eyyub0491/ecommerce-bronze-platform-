# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS dbr_dev.brazilian_ecommerce_bronze.landing
LOCATION 'abfss://brazilian-ecommerce@dlspl21databricks.dfs.core.windows.net/landing';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS dbr_dev.brazilian_ecommerce_bronze;
